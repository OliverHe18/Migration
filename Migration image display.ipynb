# %%
# import packages
import pylab
import numpy as np
from glob import glob
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import torch
import seaborn as sns

# %matplotlib inline

# %%
# single image 2d heatmap using seaborn
# input numpy ndarray or pandas dataframe

img = Image.open('test_images_1/30min.jpg')
area = (912, 240, 992, 320)
img_cropped = img.crop(area)
img_3d = np.array(img_cropped)
plt.imshow(img_3d)
plt.show()

img_2d = np.mean(img_3d, axis=2)

# %%
img_2d.shape
# Out:
# (80, 80)

# %%
sns.heatmap(img_2d)

# %%
# singe image heatmap
 
# Create data
img = Image.open('test_images_1/30min.jpg')
img_arr = np.array(img)

 
# Create heatmap
heatmap, xedges, yedges = np.histogram2d(x, y, bins=(64,64))
extent = [xedges[900], xedges[1000], yedges[200], yedges[300]]
 
# Plot heatmap
plt.clf()
plt.title('Single image heatmap example')
plt.ylabel('y')
plt.xlabel('x')
plt.imshow(heatmap, extent=extent)
plt.show()

# %%
# image-image heatmap

data_dir = 'test_images_1/'
img1 = mpimg.imread(data_dir + '30min.jpg')
img2 = mpimg.imread(data_dir + '120min.jpg')

# Calculate the absolute difference on each channel separately
error_r = np.fabs(np.subtract(img2[:,:,0], img1[:,:,0]))
error_g = np.fabs(np.subtract(img2[:,:,1], img1[:,:,1]))
error_b = np.fabs(np.subtract(img2[:,:,2], img1[:,:,2]))

# Calculate the maximum error for each pixel
lum_img = np.maximum(np.maximum(error_r, error_g), error_b)

# Uncomment the next line to turn the colors upside-down
#lum_img = np.negative(lum_img);

imgplot = plt.imshow(lum_img)

# Choose a color palette
imgplot.set_cmap('jet')
#imgplot.set_cmap('Spectral') 

plt.colorbar()
plt.axis('off')

pylab.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Vapps\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# C:\Vapps\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     239
#     240     if 'png' in formats:
# --> 241         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     242     if 'retina' in formats or 'png2x' in formats:
#     243         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# C:\Vapps\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     123
# ...

# %%
def display_image(img_path):
    img = Image.open(img_path)
    plt.imshow(img)
    plt.show()

# %%
test_images = np.array(glob('test_images_1/*'))
print('Total number of images: ', len(test_images))

# for img in np.hstack((test_images[:])):
for img in test_images[:]:
    print(str(img))
    display_image(img)
# Out:
# Total number of images:  4
# test_images_1\30min.JPG
# test_images_1\60min.JPG
# test_images_1\90min.JPG
# test_images_1\120min.JPG

# %%
print(test_images.size)
print(test_images[0])
# Out:
# 4
# test_images_1\30min.JPG

# %% [markdown]
# image: 1904 * 888
# how to crop
# how to feed into RNN
# ImageFolder -> DataLoader

# %%
# Canny edge detection in OpenCV
img_path = 'test_images_1/30min.jpg'
display_image(img_path)

img = cv2.imread(img_path)
edges = cv2.Canny(img, 50, 150)

# %%
plt.imshow(img, cmap='gray')

# %%
plt.imshow(edges, cmap='gray')
